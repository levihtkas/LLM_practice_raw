# %%
import pandas as pd
from sklearn.linear_model import LinearRegerssion
from sklearn.metrics import mean_squared_error , r2_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestRegressor
from pricer.evaluator import evaluate
from pricer.items import Item
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.linear_model import LinearRegerssion
#       3 from sklearn.metrics import mean_squared_error , r2_score
#       4 from sklearn.feature_extraction.text import CountVectorizer
#
# ImportError: cannot import name 'LinearRegerssion' from 'sklearn.linear_model' (c:\Users\vijib\projects\llm_eng_manual\.venv\Lib\site-packages\sklearn\linear_model\__init__.py)

# %%
LITE_MODE = True

# %%
username = "Sakthi100"
from datasets import Dataset, DatasetDict, load_dataset

dataset = "lite-data"
dataset = load_dataset(username+"/"+dataset)

train=dataset.get('train')
test= dataset.get('test')
# Out:
# Loaded 25,000 training items, 2,000 test items

# %%
train[0]
# Out:
# {'text': 'How much does this cost to the nearest dollar?\n\nand Replacement Range Cooktop Drip Pans fit GE, Hotpoint - Two 6 Inch and Two 8 Inch Pans (4 pieces)\nContents 2 x (6 inches) and 2 x (8 inches) bowls, 4 drip bowls total Compatibility This replacement kit works with GE, Hotpoint, Moffat, Monogram (GE), Profile (GE), RCA (GE), and Roper models prior to 1996. replaces 65975, replaces and 65974, 770169 Premium quality Drip bowls are made of durable high-quality material. It features a chrome finish, well-tested by the manufacturer. Durable, stick-free, easy to clean, and dishwasher safe. Ensure long-lasting and effective performance Easy to install Shut off electrical power, tilt the coil\n\nPrice is $12.00',
#  'price': 11.99}

# %%
import numpy as np
prices = np.array([float(item['price']) for item in train])

# %%
documents = [item['text'] for item in train]
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_features=2000, stop_words='english')
X = vectorizer.fit_transform(documents)

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 1228295 stored elements and shape (25000, 2000)>

# %%
selected_words = vectorizer.get_feature_names_out()
print(f"Number of selected words: {len(selected_words)}")
print("Selected words:", selected_words[1000:1020])
# Out:
# Number of selected words: 2000
# Selected words: ['input' 'insert' 'inside' 'install' 'installation' 'installed'
#  'installing' 'instantly' 'instead' 'instruction' 'instructions'
#  'insulation' 'insure' 'integrated' 'integrity' 'intended' 'interface'
#  'interior' 'internal' 'international']

# %%
sum_x = X.sum(axis=0).ravel()
sum_x
# Out:
# matrix([[25060,   113,   300, ...,   167,   163,   176]], shape=(1, 2000))

# %%
print(sum_x[1000:1100])
# Out:
# []

# %%
word_counts = np.asarray(X.sum(axis=0)).ravel()

top_words = sorted(
    zip(selected_words, word_counts),
    key=lambda x: x[1],
    reverse=True
)[:20]

for word, count in top_words:
    print(word, int(count))
# Out:
# replacement 32199
# does 26144
# cost 25367
# price 25281
# 00 25060
# dollar 25006
# nearest 25002
# filter 19903
# model 18896
# water 16802
# refrigerator 16232
# product 15914
# compatible 15701
# brand 15435
# dryer 14487
# whirlpool 14424
# oem 14203
# number 13928
# manufacturer 12822
# quality 11907
