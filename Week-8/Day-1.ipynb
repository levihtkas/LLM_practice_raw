# %%
import os
import locale
import modal
from dotenv import load_dotenv
load_dotenv(override=True)

# %%
print(locale.getpreferredencoding())  # Should print 'UTF-8'

# %%
os.environ["PYTHONIOENCODING"] = "utf-8"

# %%
from hello import app, hello

# %%
with app.run():
    reply = hello.local()
reply

# %%
with app.run():
    reply=hello.remote()
reply

# %%
from llama import generate,app
with modal.enable_output():
    with app.run():
        reply = generate.remote("You know me real gangstar from city to the")

reply

# %%
from agents.preprocessor import PreProcessor
preprocessor = PreProcessor(model_name="ollama/gemma3:4b")
text = preprocessor.preprocess("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(text)

# %%
from llama import generate,app

with modal.enable_output():
    with app.run():
        reply = generate.remote("Guess the price from just this info say it in dollars respond only the number description Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
reply

# %%
text

# %%
from pricer_ephemeral import app, price
with modal.enable_output():
    with app.run():
        result = price.remote(text)
result

# %% [markdown]
# ## Deployment

# %%
# !modal deploy -m price_service

# %%
pricer = modal.Function.from_name("pricer-service","price")
pricer.remote(text)

# %%
# !modal deploy -m price_service_2

# %%
Pricer = modal.Cls.from_name("pricer-service","Pricer")
pricer = Pricer()
reply = pricer.price.remote(text)
reply

# %%
reply = pricer.price.remote("a smoothy silk Vanilla icecream with flavours out of the world No Sugar and no added preservatives Healthy as it gets")
reply

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %%
from agents.specialistAgent import SpecialistAgent
agent = SpecialistAgent()
agent.price("iPhone 10")

# %%
agent.price("Moto Edge 60 Pro")

# %%
220*94
